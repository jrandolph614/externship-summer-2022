# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import itertools
import collections
#!pip install TextBlob
from textblob import TextBlob
import nltk
import tweepy as tw
import nltk
from nltk.corpus import stopwords
#nltk.download('punkt')
#nltk.download('stopwords')
#nltk.download('wordnet')
from collections import Counter


sns.set(font_scale=1.5)
sns.set_style("whitegrid")

# %%
tweets = pd.read_excel(r'/Users/saraosowski/Documents/finalTweets.xlsx')

# %%
#very very basic cleaning for this example; cleaning from escorting code was also run

def data_cleaning(df, tweets):
    df[tweets] = df[tweets].str.lower()
    df[tweets] = df[tweets].apply(lambda elem: re.sub(r"(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)|^rt|http.+?", "", elem))
    return df

# %%
#converts text to strings
tweets['string'] = tweets['text'].astype(str).values.tolist()

# %%
cleaned = data_cleaning(tweets, 'string')
print(cleaned)

#'string' column is our cleaned data
# Out:
#                                                    text  \
# 0     RT @cardilogix: 🗣️ Our team is looking to...
# 1     RT @cardilogix: 🗣️ Our team is looking to...
# 2     🗣️ Our team is looking to hire a Multimed...
# 3     #nc #dc #md #sc #fl #tn #pa #co #mo #ma #ny #n...
# 4     #nc #dc #md #sc #fl #tn #pa #co #mo #ma #ny #n...
# ...                                                 ...
# 4419  30 years ago, I was at the #SugarBowl in #NewO...
# 4420  Check out Syracuse China Harmony Sugar Bowl an...
# 4421  30 years ago I was in New Orleans getting read...
# 4422  I know #Cuse beat #AllIn this year, but, still...
# 4423  Watching #Clemson, and even though #AllIn's lo...
#
#                            date  \
# 0     2020-06-25 14:18:27+00:00
# 1     2020-06-25 14:18:10+00:00
# 2     2020-06-25 14:17:57+00:00
# 3     2017-11-20 01:32:45+00:00
# 4     2017-11-20 01:00:10+00:00
# ...                         ...
# 4419  2018-01-02 02:54:45+00:00
# ...

# %%
#word frequency 
freq = cleaned.string.str.split(expand=True).stack().value_counts().reset_index()
freq.columns = ['Word', 'Frequency'] 
freq
# Out:
#                       Word  Frequency
# 0                      the        788
# 1                       in        759
# 2                       to        757
# 3                      and        742
# 4                        i        613
# ...                    ...        ...
# 11106             thegypos          1
# 11107  alternativewasabi15          1
# 11108      kevinbarrylynch          1
# 11109         optimization          1
# 11110        yearsugarbowl          1
#
# [11111 rows x 2 columns]

# %%
top100 = freq[0:99]
# bar plot
top100.plot(kind = 'bar', x = 'Word', y = 'Frequency', color = 'red')
plt.title('Word Frequency in Sugaring Tweets')
plt.figure(figsize = (12,7))
plt.show()
