# %%
import pandas as pd
import tweepy
import time

# %%
#API
consumer_key = "DXOiPubsMSo8j939FBPOsb8Gb"
#API Secret
consumer_secret = "4zIS7j3N6mkIs2ZJsqbCAC4Jb1BU0kNol0qq90N81IfJF814Lq"
#Token
access_key = "776495568709414912-nnlmM8IIUhBNGUuaDeU9v3y2RpZCTWZ"
#Token Secret
access_secret= "6PnKUdecZj7w6TFDOkEANLFM9f0OYzL6MhafoZQ8l7bpy"

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_key, access_secret)
api = tweepy.API(auth)
client = tweepy.Client(bearer_token="AAAAAAAAAAAAAAAAAAAAAFrAZwEAAAAAf%2FrPNxA4GnQjZjxFl3lsZIXM2bA%3D94LbEadLVALxIIE4y3MdeH1tGFqioR9XzpY2B0MdybaFj7jTFz")

# %%
query = ['#EastBrunswickBears']

start_time ='2020-01-01T00:00:00Z'

end_time = '2022-04-03T00:00:00Z'

for tweet in tweepy.Paginator(client.search_all_tweets, query=query,tweet_fields = ['context_annotations', 'created_at'], start_time=start_time, end_time=end_time, max_results=100).flatten(limit=1000):
    print(str(tweet.text) + str(tweet.created_at))
# Out:
# 🔴 LIVE PODCAST: #1 St. Thomas Aquinas vs. #5 East Brunswick: GMC Girls on @Spreaker #eastbrunswickbears #njgirlsbasketball #stthomasaquinastrojans https://t.co/Invylwi1UF2022-02-22 23:57:08+00:00
# RT @GoMVB: 🚨 PLAYER SPOTLIGHT 🚨
# KRAIG WADE JR - '22 DE/H
# 6'3"  235 LBS
# #28 East Brunswick HS Bears NJ
# Bench: 275 LBS
# SQUAT: 450 LBS
# https:/…2022-01-19 01:39:17+00:00
# RT @GoMVB: ALANI AJIGBOTOSHO - 2 SPORT ATHLETE
# '23 GUARD EAST BRUNSWICK BEARS, NJ
# 6'4" - 170 LBS
# GPA: 4.0
# https://t.co/Dg4OYwXbaP
# https://t…2022-01-08 17:29:42+00:00
# RT @GoMVB: ALANI AJIGBOTOSHO - 2 SPORT ATHLETE
# '23 GUARD EAST BRUNSWICK BEARS, NJ
# 6'4" - 170 LBS
# GPA: 4.0
# https://t.co/Dg4OYwXbaP
# https://t…2022-01-07 01:35:28+00:00
# ALANI AJIGBOTOSHO - 2 SPORT ATHLETE
# '23 GUARD EAST BRUNSWICK BEARS, NJ
# 6'4" - 170 LBS
# GPA: 4.0
# https://t.co/Dg4OYwXbaP
# https://t.co/BFeSoPc62N
# Twitter: @Alani_Ajig212
# ...

# %%
expList = ['#Bae', '#babes', '#gfe', '#secretgf', '#Ship', '#Freestyle', '#Daddy', '#CollegeBaby', '#TuitionBaby', '#DS', '#AngelBaby', '#courtesan', '#findom', '#FWB', '#SplendaDaddy', '#SplendaMama', '#LTA', '#NSA', '#ORO', '#PPM', '#hookup', '#POT', '#SA', '#STA', '#paypig', '#SB', '#RoadSugar', '#TravelingArrangement', '#SugarOnTheSide', '#bear', '#SD', '#PapiDulce', '#SaltDaddy', '#SaltMama', '#SaltMommy', '#MentoringArrangement', '#SugarBowl', '#SM', '#SR', '#Companion', '#companions', '#Companionship', '#SugarPup', '#BigDaddy', '#SugarBear', '#SugarDaddiesWanted', '#SugarMommyWanted', '#SplendaMommy', '#SBSD', '#SDSB', '#massage_bodytobody', '#massagefullbodymassage', '#MintBoy', '#relaxation', '#therapeutic', '#massagefullservice', '#eroticmassage', '#massageplusplus', '#sensualmassage', '#Petite', '#Trystlink', '#Instagirls', '#Escortmodels', '#Kgs', '#Kilograms', '#Kilograms', '#Lbs', '#Models']
locList = ['#burquecity', '#flag', '#ABQ', '#DukeCity', '#TheBurque', '#NM', '#riometro', '#saltlakecity', '#purenm', '#flagstaff', '#lascreus', '#santafe', '#amarillo', '#belen', '#coloradosprings', '#fountainvalley', '#santafeopera', '#albuquerqueinternationalballoonfiesta', '#santafeindianmarket', '#santafespanishmarket', '#gatheringofnationspowwow', '#santafeinternationalfolkartmarket', '#newmexicostatefairrodeo', '#riograndeartsandcraftsfestival', '#newmexicorailrunnerexpress', '#railrunnerexpress', '#UNM', '#GoLobos', '#WearLoboRed', '#nmsu' '#prideofnewmexico', '#enmu', '#allin', '#nmhu', '#letsride', '#cowboys', '#iaia', '#stanggang', '#utep', '#GoMiners', '#CSUpueblo', '#cannonairforcebase', '#cannonafb', '#hollomanafb', '#hollomanairforcebase', '#kafb', '#kirtlandafb', '#kirtland']

# %%
hitList = [str(x)+' '+str(y) for x in expList for y in locList]

# %%
hitList
# Out:
# ['#Bae #burquecity',
#  '#Bae #flag',
#  '#Bae #ABQ',
#  '#Bae #DukeCity',
#  '#Bae #TheBurque',
#  '#Bae #NM',
#  '#Bae #riometro',
#  '#Bae #saltlakecity',
#  '#Bae #purenm',
#  '#Bae #flagstaff',
#  '#Bae #lascreus',
#  '#Bae #santafe',
#  '#Bae #amarillo',
#  '#Bae #belen',
#  '#Bae #coloradosprings',
#  '#Bae #fountainvalley',
#  '#Bae #santafeopera',
#  '#Bae #albuquerqueinternationalballoonfiesta',
#  '#Bae #santafeindianmarket',
#  '#Bae #santafespanishmarket',
#  '#Bae #gatheringofnationspowwow',
#  '#Bae #santafeinternationalfolkartmarket',
#  '#Bae #newmexicostatefairrodeo',
#  '#Bae #riograndeartsandcraftsfestival',
#  '#Bae #newmexicorailrunnerexpress',
#  '#Bae #railrunnerexpress',
#  '#Bae #UNM',
#  '#Bae #GoLobos',
#  '#Bae #WearLoboRed',
#  '#Bae #nmsu#prideofnewmexico',
#  '#Bae #enmu',
#  '#Bae #allin',
#  '#Bae #nmhu',
#  '#Bae #letsride',
#  '#Bae #cowboys',
#  '#Bae #iaia',
#  '#Bae #stanggang',
#  '#Bae #utep',
#  '#Bae #GoMiners',
#  '#Bae #CSUpueblo',
# ...

# %%
print(len(expList), len(locList), len(hitList))
# Out:
# 68 47 3196

# %%
hitList10 = hitList[102:200]
print(hitList10)
print(len(hitList10))
# Out:
# ['#gfe #purenm', '#gfe #flagstaff', '#gfe #lascreus', '#gfe #santafe', '#gfe #amarillo', '#gfe #belen', '#gfe #coloradosprings', '#gfe #fountainvalley', '#gfe #santafeopera', '#gfe #albuquerqueinternationalballoonfiesta', '#gfe #santafeindianmarket', '#gfe #santafespanishmarket', '#gfe #gatheringofnationspowwow', '#gfe #santafeinternationalfolkartmarket', '#gfe #newmexicostatefairrodeo', '#gfe #riograndeartsandcraftsfestival', '#gfe #newmexicorailrunnerexpress', '#gfe #railrunnerexpress', '#gfe #UNM', '#gfe #GoLobos', '#gfe #WearLoboRed', '#gfe #nmsu#prideofnewmexico', '#gfe #enmu', '#gfe #allin', '#gfe #nmhu', '#gfe #letsride', '#gfe #cowboys', '#gfe #iaia', '#gfe #stanggang', '#gfe #utep', '#gfe #GoMiners', '#gfe #CSUpueblo', '#gfe #cannonairforcebase', '#gfe #cannonafb', '#gfe #hollomanafb', '#gfe #hollomanairforcebase', '#gfe #kafb', '#gfe #kirtlandafb', '#gfe #kirtland', '#secretgf #burquecity', '#secretgf #flag', '#secretgf #ABQ', '#secretgf #DukeCity', '#secretgf #TheBurque', 
# ...

# %%
#query1 = ['#gfe #saltlakecity']

start_time ='2015-01-01T00:00:00Z'

end_time = '2022-04-16T00:00:00Z'

for tweet in tweepy.Paginator(client.search_all_tweets, query=query1,tweet_fields = ['context_annotations', 'created_at'], start_time=start_time, end_time=end_time, max_results=100).flatten(limit=1000):
    print(str(tweet.text) + str(tweet.created_at))
# Out:
# RT @LexxxNatasha: Available now in #SLC #CARDATE #OUTCALLS #slcescort #SaltLakeCity #AVAIL4BOOKING #Escorts #gfe #bbbj #brunette #bigbooty…2022-02-08 23:23:20+00:00
# RT @LexxxNatasha: Available now in #SLC #CARDATE #OUTCALLS #slcescort #SaltLakeCity #AVAIL4BOOKING #Escorts #gfe #bbbj #brunette #bigbooty…2022-01-29 13:28:00+00:00
# It’s the most wonderful time of the year 🎄I am available today and tomorrow. I have a cozy incall and you won’t regret seeing me! Please text (385)645-4756! ❄️☃️⛄️ #escort #saltlakecity #gfe #companion2021-12-23 18:07:40+00:00
# RT @LexxxNatasha: Available now in #SLC #CARDATE #OUTCALLS #slcescort #SaltLakeCity #AVAIL4BOOKING #Escorts #gfe #bbbj #brunette #bigbooty…2021-11-15 01:56:16+00:00
# In Salt Lake City Until Sunday.
#
# Looking forward to meeting you. 🔥
# Get in touch, text or email me. 💋
# ...

# %%
ht1 = hitList10
date_since = "2015-01-01"
numtweet = 1000

# %%
ht1
# Out:
# ['#gfe #purenm',
#  '#gfe #flagstaff',
#  '#gfe #lascreus',
#  '#gfe #santafe',
#  '#gfe #amarillo',
#  '#gfe #belen',
#  '#gfe #coloradosprings',
#  '#gfe #fountainvalley',
#  '#gfe #santafeopera',
#  '#gfe #albuquerqueinternationalballoonfiesta',
#  '#gfe #santafeindianmarket',
#  '#gfe #santafespanishmarket',
#  '#gfe #gatheringofnationspowwow',
#  '#gfe #santafeinternationalfolkartmarket',
#  '#gfe #newmexicostatefairrodeo',
#  '#gfe #riograndeartsandcraftsfestival',
#  '#gfe #newmexicorailrunnerexpress',
#  '#gfe #railrunnerexpress',
#  '#gfe #UNM',
#  '#gfe #GoLobos',
#  '#gfe #WearLoboRed',
#  '#gfe #nmsu#prideofnewmexico',
#  '#gfe #enmu',
#  '#gfe #allin',
#  '#gfe #nmhu',
#  '#gfe #letsride',
#  '#gfe #cowboys',
#  '#gfe #iaia',
#  '#gfe #stanggang',
#  '#gfe #utep',
#  '#gfe #GoMiners',
#  '#gfe #CSUpueblo',
#  '#gfe #cannonairforcebase',
#  '#gfe #cannonafb',
#  '#gfe #hollomanafb',
#  '#gfe #hollomanairforcebase',
#  '#gfe #kafb',
#  '#gfe #kirtlandafb',
# ...

# %%
def scrape(ht1, date_since, numtweet):
 
        # Creating DataFrame using pandas
        #db1 is intermediary dataframe
        db1 = pd.DataFrame(columns=['text','date'])
 
        # We are using .Cursor() to search
        # through twitter for the required tweets.
        # The number of tweets can be
        # restricted using .items(number of tweets)
        
        tweets = tweepy.Paginator(client.search_all_tweets, query=ht1, tweet_fields = ['context_annotations', 'created_at'], start_time=start_time, end_time=end_time, max_results=100).flatten(limit=1000)
            
 
        # .Cursor() returns an iterable object. Each item in
        # the iterator has various attributes
        # that you can access to
        # get information about each tweet
        list_tweets = [tweet for tweet in tweets]
 
        # Counter to maintain Tweet Count
        i = 1
 
        # we will iterate over each tweet in the
        # list for extracting information about each tweet
        for tweet in list_tweets:
                text = tweet.text
                date = tweet.created_at
                #description = tweet.user.description
                #followers = tweet.followers_count
                #hashtags = tweet.entities['hashtags']
 
                # Retweets can be distinguished by
                # a retweeted_status attribute,
                # in case it is an invalid reference,
                # except block will be executed
                
                
                #hashtext = list()
                #for j in range(0, len(hashtags)):
                 #      hashtext.append(hashtags[j]['text'])
                
                # Here we are appending all the
                # extracted information in the DataFrame
                ith_tweet = [text, date]
                db.loc[len(db)] = ith_tweet
 
                # Function call to print tweet data on screen
                #printtweetdata(i, ith_tweet)
                i = i+1
        #db is master dataframe
        db.append(db1)

# %%
db = pd.DataFrame(columns=['text','date'])

# %%
#For automated scraping
#c will count to the length of ht1 while it scrapes
#then 

start = -1
c=0
waiting = False

while c<= len(hitList10):
    if waiting:
        if (time.time() - start) >= 1:
            waiting = False
            start = time.time()
    else:
        try: 
            scrape(ht1[c], date_since, numtweet)
            c+=1
            print(c)
        except tweepy.errors.TooManyRequests:
            print('too many requests')
            waiting = True
            start = time.time()
# Out:
# 1
# too many requests
# 2
# too many requests
# 3
# too many requests
# 4
# 5
# too many requests
# 6
# too many requests
# 7
# 8
# too many requests
# 9
# too many requests
# 10
# too many requests
# 11
# too many requests
# 12
# too many requests
# 13
# too many requests
# 14
# too many requests
# 15
# too many requests
# 16
# 17
# too many requests
# 18
# too many requests
# 19
# too many requests
# 20
# too many requests
# 21
# too many requests
# 22
# too many requests
# 23
# too many requests
# 24
# too many requests
# 25
# too many requests
# 26
# too many requests
# 27
# too many requests
# 28
# too many requests
# 29
# too many requests
# 30
# 31
# too many requests
# 32
# too many requests
# 33
# too many requests
# 34
# too many requests
# 35
# too many requests
# 36
# 37
# too many requests
# 38
# too many requests
# 39
# too many requests
# 40
# too many requests
# 41
# too many requests
# 42
# 43
# too many requests
# 44
# too many requests
# 45
# too many requests
# ...

# %%
db
# Out:
#                                                  text  \
# 0   #ISO a female #escort for #gfe and full releas...
# 1   Craving travels to Salt Lake City And Santa Fe...
# 2   RT @HarleyLane_Tx: Lets have some fun 😘\n📧 har...
# 3   RT @HarleyLane_Tx: Lets have some fun 😘\n📧 har...
# 4   RT @HarleyLane_Tx: Lets have some fun 😘\n📧 har...
# ..                                                ...
# 75  After hours alcohol delivery services availabl...
# 76  Any one like heels on and off. it's #FridayFun...
# 77  RT @Diamondrosexx: Book me at the #worldfamous...
# 78  Book me at the #worldfamous @TheMustangRanch 🐎...
# 79  If you're lookin for a filly to tame, check ou...
#
#                         date
# 0  2017-05-14 16:47:27+00:00
# 1  2018-05-29 01:21:45+00:00
# 2  2021-10-28 13:34:21+00:00
# 3  2021-10-28 05:10:07+00:00
# 4  2021-10-27 19:46:31+00:00
# ..                       ...
# 75 2019-01-13 06:49:04+00:00
# 76 2017-12-23 04:29:21+00:00
# 77 2017-11-28 04:54:33+00:00
# ...

# %%
# change csv filename every time you run this cell block
filename = r'C:\Users\eman7\OneDrive\Desktop\Practicum_22\tweets_75.csv'
db.to_csv(filename)
